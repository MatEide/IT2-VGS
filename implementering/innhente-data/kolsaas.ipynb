# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
fil = open("kolsaas.csv")
data = fil.read()

# %%
linjer = data.split("\n")
tur = []
for linje in linjer:
    splittet_linje = linje.split(",")
    tur.append(splittet_linje)
tur[1][0] #-> gir meg den første tiden 0
# Out:
# '0'

# %%
tur
# Out:
# [['time', 'latitude', 'longitude', 'altitude'],
#  ['0', '59.892702', '10.517711', '6.9'],
#  ['1', '59.892702', '10.517668', '6.9'],
#  ['2', '59.892704', '10.51764', '6.8'],
#  ['3', '59.892705', '10.517612', '6.8'],
#  ['4', '59.892712', '10.517537', '6.8'],
#  ['5', '59.892715', '10.517514', '6.8'],
#  ['6', '59.892728', '10.517461', '6.8'],
#  ['7', '59.892732', '10.517447', '6.8'],
#  ['8', '59.892747', '10.517422', '6.8'],
#  ['9', '59.892755', '10.517413', '6.8'],
#  ['10', '59.892762', '10.517405', '6.8'],
#  ['11', '59.892802', '10.517397', '6.8'],
#  ['12', '59.892837', '10.517401', '6.8'],
#  ['13', '59.892848', '10.517398', '6.8'],
#  ['14', '59.892885', '10.517382', '6.8'],
#  ['15', '59.892897', '10.517378', '6.8'],
#  ['16', '59.892931', '10.517378', '6.8'],
#  ['17', '59.89294', '10.517378', '6.8'],
#  ['18', '59.892974', '10.517372', '6.8'],
#  ['19', '59.892987', '10.517369', '6.8'],
#  ['20', '59.893002', '10.51736', '6.8'],
# ...

# %%
## oppgave: plott time (tid) på x-aksen mot altitude (høyde) på y-aksen

x = []
y = []

for maalepunkt in tur[1:]:
    tid = float(maalepunkt[1])
    x.append(tid)
    høyde = float(maalepunkt[3])
    y.append(høyde)

plt.scatter(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 x = []
#       4 y = []
# ----> 6 for maalepunkt in tur[1:]:
#       7     tid = float(maalepunkt[1])
#       8     x.append(tid)
#
# NameError: name 'tur' is not defined
